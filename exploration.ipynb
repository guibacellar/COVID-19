# %%
# %matplotlib widget

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('data/all_timeline_with_features.csv')

# %%
df.columns
# Out:
# Index(['date', 'countrycode', 'countrylabel', 'totalcases', 'totaldeaths',
#        'totalrecovered', 'ft01_previous_day_totalcases',
#        'ft02_previous_day_totaldeaths', 'ft03_previous_day_totalrecovered',
#        'ft04_new_cases_per_day', 'ft05_new_deaths_per_day',
#        'ft06_new_recovered_per_day', 'ft07_previous_day_new_cases_per_day',
#        'ft08_previous_day_new_deaths_per_day',
#        'ft09_previous_day_new_recovered_per_day', 'ft10_cases_evolution_rate',
#        'ft11_deaths_evolution_rate', 'ft12_recovered_evolution_rate',
#        'ft13_death_percent'],
#       dtype='object')

# %%
COUNTRY_CODE = 'BR'

target_country = df[(df['countrycode'] == COUNTRY_CODE) & (df['totalcases'].notna())]
target_country.head(100)
# Out:
#            date countrycode countrylabel  totalcases  totaldeaths  \
# 363  2020-02-26          BR       Brazil         1.0          0.0
# 364  2020-02-27          BR       Brazil         1.0          0.0
# 365  2020-02-28          BR       Brazil         1.0          0.0
# 366  2020-02-29          BR       Brazil         2.0          0.0
# 367  2020-03-01          BR       Brazil         2.0          0.0
# 368  2020-03-02          BR       Brazil         2.0          0.0
# 369  2020-03-03          BR       Brazil         2.0          0.0
# 370  2020-03-04          BR       Brazil         4.0          0.0
# 371  2020-03-05          BR       Brazil         4.0          0.0
# 372  2020-03-06          BR       Brazil        13.0          0.0
# 373  2020-03-07          BR       Brazil        13.0          0.0
# 374  2020-03-08          BR       Brazil        20.0          0.0
# 375  2020-03-09          BR       Brazil        25.0          0.0
# 376  2020-03-10          BR       Brazil        31.0          0.0
# 377  2020-03-11          BR       Brazil        38.0          0.0
# 378  2020-03-12          BR       Brazil        52.0          0.0
# 379  2020-03-13          BR       Brazil       151.0          0.0
# 380  2020-03-14          BR       Brazil       151.0          0.0
# 381  2020-03-15          BR       Brazil       162.0          0.0
# 382  2020-03-16          BR       Brazil       200.0          0.0
# 383  2020-03-17          BR       Brazil       321.0          1.0
# 384  2020-03-18          BR       Brazil       372.0          3.0
# 385  2020-03-19          BR       Brazil       621.0          6.0
# 386  2020-03-20          BR       Brazil       793.0         11.0
# 387  2020-03-21          BR       Brazil      1021.0         15.0
# 388  2020-03-22          BR       Brazil      1021.0         15.0
#
#      totalrecovered  ft01_previous_day_totalcases  \
# 363             0.0                           NaN
# 364             0.0                           1.0
# 365             0.0                           1.0
# 366             0.0                           1.0
# 367             0.0                           2.0
# 368             0.0                           2.0
# 369             0.0                           2.0
# 370             0.0                           2.0
# 371             0.0                           4.0
# 372             0.0                           4.0
# 373             0.0                          13.0
# 374             0.0                          13.0
# 375             0.0                          20.0
# 376             0.0                          25.0
# 377             0.0                          31.0
# 378             0.0                          38.0
# 379             0.0                          52.0
# 380             0.0                         151.0
# 381             0.0                         151.0
# 382             1.0                         162.0
# 383             2.0                         200.0
# 384             2.0                         321.0
# 385             2.0                         372.0
# 386             2.0                         621.0
# 387             2.0                         793.0
# 388             2.0                        1021.0
#
#      ft02_previous_day_totaldeaths  ft03_previous_day_totalrecovered  \
# 363                            NaN                               NaN
# 364                            0.0                               0.0
# 365                            0.0                               0.0
# 366                            0.0                               0.0
# 367                            0.0                               0.0
# 368                            0.0                               0.0
# 369                            0.0                               0.0
# 370                            0.0                               0.0
# 371                            0.0                               0.0
# 372                            0.0                               0.0
# 373                            0.0                               0.0
# 374                            0.0                               0.0
# 375                            0.0                               0.0
# 376                            0.0                               0.0
# 377                            0.0                               0.0
# 378                            0.0                               0.0
# 379                            0.0                               0.0
# 380                            0.0                               0.0
# 381                            0.0                               0.0
# 382                            0.0                               0.0
# 383                            0.0                               1.0
# 384                            1.0                               2.0
# 385                            3.0                               2.0
# 386                            6.0                               2.0
# 387                           11.0                               2.0
# 388                           15.0                               2.0
#
#      ft04_new_cases_per_day  ft05_new_deaths_per_day  \
# 363                     NaN                      NaN
# 364                     0.0                      0.0
# 365                     0.0                      0.0
# 366                     1.0                      0.0
# 367                     0.0                      0.0
# 368                     0.0                      0.0
# 369                     0.0                      0.0
# 370                     2.0                      0.0
# 371                     0.0                      0.0
# 372                     9.0                      0.0
# 373                     0.0                      0.0
# 374                     7.0                      0.0
# 375                     5.0                      0.0
# 376                     6.0                      0.0
# 377                     7.0                      0.0
# 378                    14.0                      0.0
# 379                    99.0                      0.0
# 380                     0.0                      0.0
# 381                    11.0                      0.0
# 382                    38.0                      0.0
# 383                   121.0                      1.0
# 384                    51.0                      2.0
# 385                   249.0                      3.0
# 386                   172.0                      5.0
# 387                   228.0                      4.0
# 388                     0.0                      0.0
#
#      ft06_new_recovered_per_day  ft07_previous_day_new_cases_per_day  \
# 363                         NaN                                  NaN
# 364                         0.0                                  NaN
# 365                         0.0                                  0.0
# 366                         0.0                                  0.0
# 367                         0.0                                  1.0
# 368                         0.0                                  0.0
# 369                         0.0                                  0.0
# 370                         0.0                                  0.0
# 371                         0.0                                  2.0
# 372                         0.0                                  0.0
# 373                         0.0                                  9.0
# 374                         0.0                                  0.0
# 375                         0.0                                  7.0
# 376                         0.0                                  5.0
# 377                         0.0                                  6.0
# 378                         0.0                                  7.0
# 379                         0.0                                 14.0
# 380                         0.0                                 99.0
# 381                         0.0                                  0.0
# 382                         1.0                                 11.0
# 383                         1.0                                 38.0
# 384                         0.0                                121.0
# 385                         0.0                                 51.0
# 386                         0.0                                249.0
# 387                         0.0                                172.0
# 388                         0.0                                228.0
#
#      ft08_previous_day_new_deaths_per_day  \
# 363                                   NaN
# 364                                   NaN
# 365                                   0.0
# 366                                   0.0
# 367                                   0.0
# 368                                   0.0
# 369                                   0.0
# 370                                   0.0
# 371                                   0.0
# 372                                   0.0
# 373                                   0.0
# 374                                   0.0
# 375                                   0.0
# 376                                   0.0
# 377                                   0.0
# 378                                   0.0
# 379                                   0.0
# 380                                   0.0
# 381                                   0.0
# 382                                   0.0
# 383                                   0.0
# 384                                   1.0
# 385                                   2.0
# 386                                   3.0
# 387                                   5.0
# 388                                   4.0
#
#      ft09_previous_day_new_recovered_per_day  ft10_cases_evolution_rate  \
# 363                                      NaN                        NaN
# 364                                      NaN                   1.000000
# 365                                      0.0                   1.000000
# 366                                      0.0                   2.000000
# 367                                      0.0                   1.000000
# 368                                      0.0                   1.000000
# 369                                      0.0                   1.000000
# 370                                      0.0                   2.000000
# 371                                      0.0                   1.000000
# 372                                      0.0                   3.250000
# 373                                      0.0                   1.000000
# 374                                      0.0                   1.538462
# 375                                      0.0                   1.250000
# 376                                      0.0                   1.240000
# 377                                      0.0                   1.225806
# 378                                      0.0                   1.368421
# 379                                      0.0                   2.903846
# 380                                      0.0                   1.000000
# 381                                      0.0                   1.072848
# 382                                      0.0                   1.234568
# 383                                      1.0                   1.605000
# 384                                      1.0                   1.158879
# 385                                      0.0                   1.669355
# 386                                      0.0                   1.276973
# 387                                      0.0                   1.287516
# 388                                      0.0                   1.000000
#
#      ft11_deaths_evolution_rate  ft12_recovered_evolution_rate  \
# 363                         NaN                            NaN
# 364                         NaN                            NaN
# 365                         NaN                            NaN
# 366                         NaN                            NaN
# 367                         NaN                            NaN
# 368                         NaN                            NaN
# 369                         NaN                            NaN
# 370                         NaN                            NaN
# 371                         NaN                            NaN
# 372                         NaN                            NaN
# 373                         NaN                            NaN
# 374                         NaN                            NaN
# 375                         NaN                            NaN
# 376                         NaN                            NaN
# 377                         NaN                            NaN
# 378                         NaN                            NaN
# 379                         NaN                            NaN
# 380                         NaN                            NaN
# 381                         NaN                            NaN
# 382                         NaN                            inf
# 383                         inf                            2.0
# 384                    3.000000                            1.0
# 385                    2.000000                            1.0
# 386                    1.833333                            1.0
# 387                    1.363636                            1.0
# 388                    1.000000                            1.0
#
#      ft13_death_percent
# 363            0.000000
# 364            0.000000
# 365            0.000000
# 366            0.000000
# 367            0.000000
# 368            0.000000
# 369            0.000000
# 370            0.000000
# 371            0.000000
# 372            0.000000
# 373            0.000000
# 374            0.000000
# 375            0.000000
# 376            0.000000
# 377            0.000000
# 378            0.000000
# 379            0.000000
# 380            0.000000
# 381            0.000000
# 382            0.000000
# 383            0.311526
# 384            0.806452
# 385            0.966184
# 386            1.387137
# 387            1.469148
# 388            1.469148

# %%
# Cases VS Deaths
fig, ax1 = plt.subplots(figsize=(9, 7),constrained_layout=True)  # Set Figure Size
plt.xticks(rotation=45)  # Rotate X Label

fig.suptitle(f"[{COUNTRY_CODE}] - Cases VS Death's")

# Total Cases
ax1.plot(
    target_country['date'],
    target_country['totalcases'],
    color='blue',
    marker='d'
)
ax1.set_xlabel('Dates')  
ax1.set_ylabel("Infection Cases", color='blue')
ax1.tick_params(axis='y', labelcolor='blue')


# TOtal Deaths
ax2 = ax1.twinx()
ax2.plot(
    target_country['date'],
    target_country['totaldeaths'],
    color='red',
    marker='+',
    label="Death's"
)
ax2.set_ylabel("Death's", color='red')
ax2.tick_params(axis='y', labelcolor='red')


# Fig2 - Evolution Rate Day
fig2, ax3 = plt.subplots(figsize=(9, 3),constrained_layout=True)  # Set Figure Size
plt.xticks(rotation=45)  # Rotate X Label

fig2.suptitle(f"[{COUNTRY_CODE}] - Death Rate per Day (%)")
ax3.plot(
    target_country['date'],
    target_country['ft13_death_percent'],
    color='red',
    marker='o',
    label="Rate"
)
ax3.set_ylabel("Rate", color='red')
ax3.tick_params(axis='y', labelcolor='red')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# New Cases per Day
fig, ax1 = plt.subplots(figsize=(9, 7),constrained_layout=True)  # Set Figure Size
plt.xticks(rotation=45)  # Rotate X Label

fig.suptitle(f"[{COUNTRY_CODE}] - New Cases per Day")

# Total Cases
ax1.plot(
    target_country['date'],
    target_country['totalcases'],
    color='blue',
    marker='d'
)
ax1.set_xlabel('Dates')  
ax1.set_ylabel("Infection Cases", color='blue')
ax1.tick_params(axis='y', labelcolor='blue')


# New Cases per Day
ax2 = ax1.twinx()
ax2.scatter(
    target_country['date'],
    target_country['ft04_new_cases_per_day'],
    color='red',
    marker='P'
)
ax2.set_ylabel("New Cases per Day", color='red')
ax2.tick_params(axis='y', labelcolor='red')


# Fig2 - Death Rate per Day
fig2, ax3 = plt.subplots(figsize=(9, 3),constrained_layout=True)  # Set Figure Size
plt.xticks(rotation=45)  # Rotate X Label

fig2.suptitle(f"[{COUNTRY_CODE}] - Cases Evolution Rate")
ax3.plot(
    target_country['date'],
    target_country['ft10_cases_evolution_rate'],
    color='red',
    marker='o'
)
ax3.set_ylabel("Rate", color='red')
ax3.tick_params(axis='y', labelcolor='red')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
DAQUI PARA BAIXO ESTA COM PROBLEMA!!!
# Out:
#   File "<ipython-input-7-3bc708d90efd>", line 1
#     DAQUI PARA BAIXO ESTA COM PROBLEMA!!!
#              ^
# SyntaxError: invalid syntax

# %%
# Cases Vs Case Evolution Rate
fig, ax1 = plt.subplots(figsize=(9, 7),constrained_layout=True)  # Set Figure Size
plt.xticks(rotation=45)  # Rotate X Label

fig.suptitle(f"[{COUNTRY_CODE}] - Cases VS Evolution Rate")

# Evolution Rate 
ax1.bar(
    target_country['date'],
    target_country['evolution_rate_previous_day'],
    color='red'
)
ax1.set_ylabel("Evolution Rate", color='red')
ax1.tick_params(axis='y', labelcolor='red')


# Total Cases
ax2 = ax1.twinx()
ax2.plot(
    target_country['date'],
    target_country['totalcases'],
    color='blue',
    marker='d'
)
ax2.set_xlabel('Dates')  
ax2.set_ylabel("Infection Cases", color='blue')
ax2.tick_params(axis='y', labelcolor='blue')
